# %%
import pandas as pd

# %%
links = pd.read_csv('train.csv').wiki_url.unique().tolist()[2:]
links[:5]
# Out:
# ['http://en.wikipedia.org/wiki/Germany',
#  'http://en.wikipedia.org/wiki/United_Kingdom',
#  'http://en.wikipedia.org/wiki/Brussels',
#  'http://en.wikipedia.org/wiki/European_Commission',
#  'http://en.wikipedia.org/wiki/European_Union']

# %%
titles = [' '.join(link[29:].split('_')) for link in links]
titles[:5]
# Out:
# ['Germany',
#  'United Kingdom',
#  'Brussels',
#  'European Commission',
#  'European Union']

# %%
redirect = pd.read_csv('enwiki_redirects.tsv', sep='\t', header=None)
redirect.head(5)
# Out:
#                                 0                 1
# 0                               !  Exclamation mark
# 1        ! (CONFIG.SYS directive)        CONFIG.SYS
# 2            ! (Donnie Vie Album)        Donnie Vie
# 3            ! (Donnie Vie album)        Donnie Vie
# 4  ! (The Song Formerly Known As)      Unit (album)

# %%
wiki_des= pd.read_csv('wiki_items.csv')
wiki_des.head()
# Out:
#    item_id  en_label                                     en_description  \
# 0        1  Universe                 totality of space and all contents
# 1        2     Earth      third planet from the Sun in the Solar System
# 2        3      life  matter capable of extracting energy from the e...
# 3        4     death             permanent cessation of vital functions
# 4        5     human  common name of Homo sapiens, unique extant spe...
#
#   wikipedia_title
# 0        Universe
# 1           Earth
# 2            Life
# 3           Death
# 4           Human

# %%
title_pd = pd.DataFrame(links, titles).reset_index()
title_pd.columns = ['title', 'link']
title_pd
# Out:
#                         title  \
# 0                     Germany
# 1              United Kingdom
# 2                    Brussels
# 3         European Commission
# 4              European Union
# ...                       ...
# 3985           Tadayuki Okada
# 3986             Carlos Checa
# 3987             Shinichi Ito
# 3988         Bob May (golfer)
# 3989  Bradley Hughes (golfer)
#
#                                                    link
# 0                  http://en.wikipedia.org/wiki/Germany
# 1           http://en.wikipedia.org/wiki/United_Kingdom
# 2                 http://en.wikipedia.org/wiki/Brussels
# 3      http://en.wikipedia.org/wiki/European_Commission
# 4           http://en.wikipedia.org/wiki/European_Union
# ...                                                 ...
# 3985        http://en.wikipedia.org/wiki/Tadayuki_Okada
# 3986          http://en.wikipedia.org/wiki/Carlos_Checa
# 3987          http://en.wikipedia.org/wiki/Shinichi_Ito
# 3988      http://en.wikipedia.org/wiki/Bob_May_(golfer)
# 3989  http://en.wikipedia.org/wiki/Bradley_Hughes_(g...
#
# [3990 rows x 2 columns]

# %%
merged_wiki = wiki_des.merge(title_pd, left_on='wikipedia_title', right_on='title', how='right')
merged_wiki = merged_wiki.drop(columns=[ 'en_label', 'title'])
merged_wiki['en_description'].fillna(merged_wiki['wikipedia_title'], inplace=True)

merged_wiki
# Out:
#       item_id                                     en_description  \
# 0         183  federal parliamentary republic in central-west...
# 1         145  constitutional monarchy in Western Europe; for...
# 2         240  federal region of Belgium comprising 19 munici...
# 3        8880  executive branch of the European Union, respon...
# 4         458  economic and political union of states mostly ...
# ...       ...                                                ...
# 3985   934327                          Japanese motorcycle racer
# 3986   461580                                   Motorcycle rider
# 3987  1334813                          Japanese motorcycle racer
# 3988  4933296                                professional golfer
# 3989  4954949                                professional golfer
#
#               wikipedia_title  \
# 0                     Germany
# 1              United Kingdom
# 2                    Brussels
# 3         European Commission
# 4              European Union
# ...                       ...
# 3985           Tadayuki Okada
# 3986             Carlos Checa
# 3987             Shinichi Ito
# 3988         Bob May (golfer)
# 3989  Bradley Hughes (golfer)
#
#                                                    link
# 0                  http://en.wikipedia.org/wiki/Germany
# 1           http://en.wikipedia.org/wiki/United_Kingdom
# 2                 http://en.wikipedia.org/wiki/Brussels
# 3      http://en.wikipedia.org/wiki/European_Commission
# 4           http://en.wikipedia.org/wiki/European_Union
# ...                                                 ...
# 3985        http://en.wikipedia.org/wiki/Tadayuki_Okada
# 3986          http://en.wikipedia.org/wiki/Carlos_Checa
# 3987          http://en.wikipedia.org/wiki/Shinichi_Ito
# 3988      http://en.wikipedia.org/wiki/Bob_May_(golfer)
# 3989  http://en.wikipedia.org/wiki/Bradley_Hughes_(g...
#
# [3990 rows x 4 columns]

# %%
merged_wiki.to_csv('train_wiki.csv', index=False)

# %%
merged_wiki = pd.read_csv('train_wiki.csv')

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load pre-trained BERT model and tokenizer
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
from tqdm.auto import tqdm

# %%
batch_size = 16
all_embeddings = []

for i in tqdm(range(0, len(merged_wiki), batch_size)):
    batch_df = merged_wiki['en_description'].iloc[i:i+batch_size].tolist()
    try:
        # Tokenize the batch of sentences
        tokens = tokenizer(batch_df, return_tensors="pt", padding=True, truncation=True)

        # Get the embeddings from the model
        outputs = model(**tokens)

        # Extract the [CLS] token embeddings for the entire batch
        cls_embeddings = outputs.last_hidden_state[:, 0, :].detach()
        all_embeddings.append(cls_embeddings)

    except:
        print(batch_df)

    print(f"Batch {i//batch_size + 1} embeddings:", cls_embeddings.shape)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 1 embeddings: torch.Size([16, 768])
# Batch 2 embeddings: torch.Size([16, 768])
# Batch 3 embeddings: torch.Size([16, 768])
# Batch 4 embeddings: torch.Size([16, 768])
# Batch 5 embeddings: torch.Size([16, 768])
# Batch 6 embeddings: torch.Size([16, 768])
# Batch 7 embeddings: torch.Size([16, 768])
# Batch 8 embeddings: torch.Size([16, 768])
# Batch 9 embeddings: torch.Size([16, 768])
# Batch 10 embeddings: torch.Size([16, 768])
# Batch 11 embeddings: torch.Size([16, 768])
# Batch 12 embeddings: torch.Size([16, 768])
# Batch 13 embeddings: torch.Size([16, 768])
# Batch 14 embeddings: torch.Size([16, 768])
# Batch 15 embeddings: torch.Size([16, 768])
# Batch 16 embeddings: torch.Size([16, 768])
# Batch 17 embeddings: torch.Size([16, 768])
# Batch 18 embeddings: torch.Size([16, 768])
# Batch 19 embeddings: torch.Size([16, 768])
# Batch 20 embeddings: torch.Size([16, 768])
# Batch 21 embeddings: torch.Size([16, 768])
# Batch 22 embeddings: torch.Size([16, 768])
# Batch 23 embeddings: torch.Size([16, 768])
# Batch 24 embeddings: torch.Size([16, 768])
# Batch 25 embeddings: torch.Size([16, 768])
# Batch 26 embeddings: torch.Size([16, 768])
# Batch 27 embeddings: torch.Size([16, 768])
# Batch 28 embeddings: torch.Size([16, 768])
# Batch 29 embeddings: torch.Size([16, 768])
# Batch 30 embeddings: torch.Size([16, 768])
# Batch 31 embeddings: torch.Size([16, 768])
# Batch 32 embeddings: torch.Size([16, 768])
# Batch 33 embeddings: torch.Size([16, 768])
# Batch 34 embeddings: torch.Size([16, 768])
# Batch 35 embeddings: torch.Size([16, 768])
# Batch 36 embeddings: torch.Size([16, 768])
# Batch 37 embeddings: torch.Size([16, 768])
# Batch 38 embeddings: torch.Size([16, 768])
# Batch 39 embeddings: torch.Size([16, 768])
# Batch 40 embeddings: torch.Size([16, 768])
# Batch 41 embeddings: torch.Size([16, 768])
# Batch 42 embeddings: torch.Size([16, 768])
# Batch 43 embeddings: torch.Size([16, 768])
# Batch 44 embeddings: torch.Size([16, 768])
# Batch 45 embeddings: torch.Size([16, 768])
# Batch 46 embeddings: torch.Size([16, 768])
# Batch 47 embeddings: torch.Size([16, 768])
# Batch 48 embeddings: torch.Size([16, 768])
# Batch 49 embeddings: torch.Size([16, 768])
# Batch 50 embeddings: torch.Size([16, 768])
# Batch 51 embeddings: torch.Size([16, 768])
# Batch 52 embeddings: torch.Size([16, 768])
# Batch 53 embeddings: torch.Size([16, 768])
# Batch 54 embeddings: torch.Size([16, 768])
# Batch 55 embeddings: torch.Size([16, 768])
# Batch 56 embeddings: torch.Size([16, 768])
# Batch 57 embeddings: torch.Size([16, 768])
# Batch 58 embeddings: torch.Size([16, 768])
# Batch 59 embeddings: torch.Size([16, 768])
# Batch 60 embeddings: torch.Size([16, 768])
# Batch 61 embeddings: torch.Size([16, 768])
# Batch 62 embeddings: torch.Size([16, 768])
# Batch 63 embeddings: torch.Size([16, 768])
# Batch 64 embeddings: torch.Size([16, 768])
# Batch 65 embeddings: torch.Size([16, 768])
# Batch 66 embeddings: torch.Size([16, 768])
# Batch 67 embeddings: torch.Size([16, 768])
# Batch 68 embeddings: torch.Size([16, 768])
# Batch 69 embeddings: torch.Size([16, 768])
# Batch 70 embeddings: torch.Size([16, 768])
# Batch 71 embeddings: torch.Size([16, 768])
# Batch 72 embeddings: torch.Size([16, 768])
# Batch 73 embeddings: torch.Size([16, 768])
# Batch 74 embeddings: torch.Size([16, 768])
# Batch 75 embeddings: torch.Size([16, 768])
# Batch 76 embeddings: torch.Size([16, 768])
# Batch 77 embeddings: torch.Size([16, 768])
# Batch 78 embeddings: torch.Size([16, 768])
# Batch 79 embeddings: torch.Size([16, 768])
# Batch 80 embeddings: torch.Size([16, 768])
# Batch 81 embeddings: torch.Size([16, 768])
# Batch 82 embeddings: torch.Size([16, 768])
# Batch 83 embeddings: torch.Size([16, 768])
# Batch 84 embeddings: torch.Size([16, 768])
# Batch 85 embeddings: torch.Size([16, 768])
# Batch 86 embeddings: torch.Size([16, 768])
# Batch 87 embeddings: torch.Size([16, 768])
# Batch 88 embeddings: torch.Size([16, 768])
# Batch 89 embeddings: torch.Size([16, 768])
# Batch 90 embeddings: torch.Size([16, 768])
# Batch 91 embeddings: torch.Size([16, 768])
# Batch 92 embeddings: torch.Size([16, 768])
# Batch 93 embeddings: torch.Size([16, 768])
# Batch 94 embeddings: torch.Size([16, 768])
# Batch 95 embeddings: torch.Size([16, 768])
# Batch 96 embeddings: torch.Size([16, 768])
# Batch 97 embeddings: torch.Size([16, 768])
# Batch 98 embeddings: torch.Size([16, 768])
# Batch 99 embeddings: torch.Size([16, 768])
# Batch 100 embeddings: torch.Size([16, 768])
# Batch 101 embeddings: torch.Size([16, 768])
# Batch 102 embeddings: torch.Size([16, 768])
# Batch 103 embeddings: torch.Size([16, 768])
# Batch 104 embeddings: torch.Size([16, 768])
# Batch 105 embeddings: torch.Size([16, 768])
# Batch 106 embeddings: torch.Size([16, 768])
# Batch 107 embeddings: torch.Size([16, 768])
# Batch 108 embeddings: torch.Size([16, 768])
# Batch 109 embeddings: torch.Size([16, 768])
# Batch 110 embeddings: torch.Size([16, 768])
# Batch 111 embeddings: torch.Size([16, 768])
# Batch 112 embeddings: torch.Size([16, 768])
# Batch 113 embeddings: torch.Size([16, 768])
# Batch 114 embeddings: torch.Size([16, 768])
# Batch 115 embeddings: torch.Size([16, 768])
# Batch 116 embeddings: torch.Size([16, 768])
# Batch 117 embeddings: torch.Size([16, 768])
# Batch 118 embeddings: torch.Size([16, 768])
# Batch 119 embeddings: torch.Size([16, 768])
# Batch 120 embeddings: torch.Size([16, 768])
# Batch 121 embeddings: torch.Size([16, 768])
# Batch 122 embeddings: torch.Size([16, 768])
# Batch 123 embeddings: torch.Size([16, 768])
# Batch 124 embeddings: torch.Size([16, 768])
# Batch 125 embeddings: torch.Size([16, 768])
# Batch 126 embeddings: torch.Size([16, 768])
# Batch 127 embeddings: torch.Size([16, 768])
# Batch 128 embeddings: torch.Size([16, 768])
# Batch 129 embeddings: torch.Size([16, 768])
# Batch 130 embeddings: torch.Size([16, 768])
# Batch 131 embeddings: torch.Size([16, 768])
# Batch 132 embeddings: torch.Size([16, 768])
# Batch 133 embeddings: torch.Size([16, 768])
# Batch 134 embeddings: torch.Size([16, 768])
# Batch 135 embeddings: torch.Size([16, 768])
# Batch 136 embeddings: torch.Size([16, 768])
# Batch 137 embeddings: torch.Size([16, 768])
# Batch 138 embeddings: torch.Size([16, 768])
# Batch 139 embeddings: torch.Size([16, 768])
# Batch 140 embeddings: torch.Size([16, 768])
# Batch 141 embeddings: torch.Size([16, 768])
# Batch 142 embeddings: torch.Size([16, 768])
# Batch 143 embeddings: torch.Size([16, 768])
# Batch 144 embeddings: torch.Size([16, 768])
# Batch 145 embeddings: torch.Size([16, 768])
# Batch 146 embeddings: torch.Size([16, 768])
# Batch 147 embeddings: torch.Size([16, 768])
# Batch 148 embeddings: torch.Size([16, 768])
# Batch 149 embeddings: torch.Size([16, 768])
# Batch 150 embeddings: torch.Size([16, 768])
# Batch 151 embeddings: torch.Size([16, 768])
# Batch 152 embeddings: torch.Size([16, 768])
# Batch 153 embeddings: torch.Size([16, 768])
# Batch 154 embeddings: torch.Size([16, 768])
# Batch 155 embeddings: torch.Size([16, 768])
# Batch 156 embeddings: torch.Size([16, 768])
# Batch 157 embeddings: torch.Size([16, 768])
# Batch 158 embeddings: torch.Size([16, 768])
# Batch 159 embeddings: torch.Size([16, 768])
# Batch 160 embeddings: torch.Size([16, 768])
# Batch 161 embeddings: torch.Size([16, 768])
# Batch 162 embeddings: torch.Size([16, 768])
# Batch 163 embeddings: torch.Size([16, 768])
# Batch 164 embeddings: torch.Size([16, 768])
# Batch 165 embeddings: torch.Size([16, 768])
# Batch 166 embeddings: torch.Size([16, 768])
# Batch 167 embeddings: torch.Size([16, 768])
# Batch 168 embeddings: torch.Size([16, 768])
# Batch 169 embeddings: torch.Size([16, 768])
# Batch 170 embeddings: torch.Size([16, 768])
# Batch 171 embeddings: torch.Size([16, 768])
# Batch 172 embeddings: torch.Size([16, 768])
# Batch 173 embeddings: torch.Size([16, 768])
# Batch 174 embeddings: torch.Size([16, 768])
# Batch 175 embeddings: torch.Size([16, 768])
# Batch 176 embeddings: torch.Size([16, 768])
# Batch 177 embeddings: torch.Size([16, 768])
# Batch 178 embeddings: torch.Size([16, 768])
# Batch 179 embeddings: torch.Size([16, 768])
# Batch 180 embeddings: torch.Size([16, 768])
# Batch 181 embeddings: torch.Size([16, 768])
# Batch 182 embeddings: torch.Size([16, 768])
# Batch 183 embeddings: torch.Size([16, 768])
# Batch 184 embeddings: torch.Size([16, 768])
# Batch 185 embeddings: torch.Size([16, 768])
# Batch 186 embeddings: torch.Size([16, 768])
# Batch 187 embeddings: torch.Size([16, 768])
# Batch 188 embeddings: torch.Size([16, 768])
# Batch 189 embeddings: torch.Size([16, 768])
# Batch 190 embeddings: torch.Size([16, 768])
# Batch 191 embeddings: torch.Size([16, 768])
# Batch 192 embeddings: torch.Size([16, 768])
# Batch 193 embeddings: torch.Size([16, 768])
# Batch 194 embeddings: torch.Size([16, 768])
# Batch 195 embeddings: torch.Size([16, 768])
# Batch 196 embeddings: torch.Size([16, 768])
# Batch 197 embeddings: torch.Size([16, 768])
# Batch 198 embeddings: torch.Size([16, 768])
# Batch 199 embeddings: torch.Size([16, 768])
# Batch 200 embeddings: torch.Size([16, 768])
# Batch 201 embeddings: torch.Size([16, 768])
# Batch 202 embeddings: torch.Size([16, 768])
# Batch 203 embeddings: torch.Size([16, 768])
# Batch 204 embeddings: torch.Size([16, 768])
# Batch 205 embeddings: torch.Size([16, 768])
# Batch 206 embeddings: torch.Size([16, 768])
# Batch 207 embeddings: torch.Size([16, 768])
# Batch 208 embeddings: torch.Size([16, 768])
# Batch 209 embeddings: torch.Size([16, 768])
# Batch 210 embeddings: torch.Size([16, 768])
# Batch 211 embeddings: torch.Size([16, 768])
# Batch 212 embeddings: torch.Size([16, 768])
# Batch 213 embeddings: torch.Size([16, 768])
# Batch 214 embeddings: torch.Size([16, 768])
# Batch 215 embeddings: torch.Size([16, 768])
# Batch 216 embeddings: torch.Size([16, 768])
# Batch 217 embeddings: torch.Size([16, 768])
# Batch 218 embeddings: torch.Size([16, 768])
# Batch 219 embeddings: torch.Size([16, 768])
# Batch 220 embeddings: torch.Size([16, 768])
# Batch 221 embeddings: torch.Size([16, 768])
# Batch 222 embeddings: torch.Size([16, 768])
# Batch 223 embeddings: torch.Size([16, 768])
# Batch 224 embeddings: torch.Size([16, 768])
# Batch 225 embeddings: torch.Size([16, 768])
# Batch 226 embeddings: torch.Size([16, 768])
# Batch 227 embeddings: torch.Size([16, 768])
# Batch 228 embeddings: torch.Size([16, 768])
# Batch 229 embeddings: torch.Size([16, 768])
# Batch 230 embeddings: torch.Size([16, 768])
# Batch 231 embeddings: torch.Size([16, 768])
# Batch 232 embeddings: torch.Size([16, 768])
# Batch 233 embeddings: torch.Size([16, 768])
# Batch 234 embeddings: torch.Size([16, 768])
# Batch 235 embeddings: torch.Size([16, 768])
# Batch 236 embeddings: torch.Size([16, 768])
# Batch 237 embeddings: torch.Size([16, 768])
# Batch 238 embeddings: torch.Size([16, 768])
# Batch 239 embeddings: torch.Size([16, 768])
# Batch 240 embeddings: torch.Size([16, 768])
# Batch 241 embeddings: torch.Size([16, 768])
# Batch 242 embeddings: torch.Size([16, 768])
# Batch 243 embeddings: torch.Size([16, 768])
# Batch 244 embeddings: torch.Size([16, 768])
# Batch 245 embeddings: torch.Size([16, 768])
# Batch 246 embeddings: torch.Size([16, 768])
# Batch 247 embeddings: torch.Size([16, 768])
# Batch 248 embeddings: torch.Size([16, 768])
# Batch 249 embeddings: torch.Size([16, 768])
# Batch 250 embeddings: torch.Size([6, 768])

# %%
all_embeddings_tensor = torch.concatenate(all_embeddings, axis=0)
print(all_embeddings_tensor.shape)
# Save the tensor to a .pt file
torch.save(all_embeddings_tensor, "embeddings.pt")
# Out:
# torch.Size([3990, 768])
